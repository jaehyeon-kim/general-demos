# %% [markdown]
# ## Composite Transforms

# %%
import apache_beam as beam
import apache_beam.runners.interactive.interactive_beam as ib
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner

# %%
def split_row(e: str):
    return e.split(",")

# %%
p = beam.Pipeline(InteractiveRunner())

input_collection = (
    p
    | "Read from file" >> beam.io.ReadFromText("dept_data.txt")
    | "Split by comma" >> beam.Map(split_row)
)

## branching
accounts_count = (
    input_collection
    | "Filter by account" >> beam.Filter(lambda r: r[3] == "Accounts")
    ## duplicate transform logic
    | "Pair each account employee with 1" >> beam.Map(lambda e: (e[1], 1))
    | "Count by account employee" >> beam.CombinePerKey(sum)
)

hr_count = (
    input_collection
    | "Filter by hr" >> beam.Filter(lambda r: r[3] == "HR")
    ## duplicate transform logic
    | "Pair each hr employee with 1" >> beam.Map(lambda e: (e[1], 1))
    | "Count by hr employee" >> beam.CombinePerKey(sum)
)

ib.show_graph(p)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_170e8ee41c8b963f8a824260fa74e882">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show_graph</span>
#             </div>
# /usr/bin/dot
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="472pt" height="886pt"
#  viewBox="0.00 0.00 471.50 886.48" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 882.48)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-882.48 467.5,-882.48 467.5,4 -4,4"/>
# <!-- [12]: Read from file -->
# <g id="node1" class="node">
# <title>[12]: Read from file</title>
# <polygon fill="none" stroke="blue" points="327.5,-878.48 200.5,-878.48 200.5,-842.48 327.5,-842.48 327.5,-878.48"/>
# <text text-anchor="middle" x="264" y="-856.78" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Read from file</text>
# </g>
# <!-- pcoll9226 -->
# <g id="node2" class="node">
# <title>pcoll9226</title>
# <ellipse fill="none" stroke="blue" cx="264" cy="-788.48" rx="18" ry="18"/>
# </g>
# <!-- [12]: Read from file&#45;&gt;pcoll9226 -->
# <g id="edge1" class="edge">
# <title>[12]: Read from file&#45;&gt;pcoll9226</title>
# <path fill="none" stroke="black" d="M264,-842.17C264,-834.46 264,-825.19 264,-816.59"/>
# <polygon fill="black" stroke="black" points="267.5,-816.58 264,-806.58 260.5,-816.58 267.5,-816.58"/>
# </g>
# <!-- [12]: Split by comma -->
# <g id="node3" class="node">
# <title>[12]: Split by comma</title>
# <polygon fill="none" stroke="blue" points="331,-734.48 197,-734.48 197,-698.48 331,-698.48 331,-734.48"/>
# <text text-anchor="middle" x="264" y="-712.78" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Split by comma</text>
# </g>
# <!-- pcoll9226&#45;&gt;[12]: Split by comma -->
# <g id="edge2" class="edge">
# <title>pcoll9226&#45;&gt;[12]: Split by comma</title>
# <path fill="none" stroke="black" d="M264,-770.17C264,-762.46 264,-753.19 264,-744.59"/>
# <polygon fill="black" stroke="black" points="267.5,-744.58 264,-734.58 260.5,-744.58 267.5,-744.58"/>
# </g>
# <!-- input_collection -->
# <g id="node4" class="node">
# <title>input_collection</title>
# <ellipse fill="none" stroke="blue" cx="264" cy="-594.88" rx="67.69" ry="67.69"/>
# <text text-anchor="middle" x="264" y="-591.18" font-family="Times,serif" font-size="14.00" fill="blue">input_collection</text>
# </g>
# <!-- [12]: Split by comma&#45;&gt;input_collection -->
# <g id="edge3" class="edge">
# <title>[12]: Split by comma&#45;&gt;input_collection</title>
# <path fill="none" stroke="black" d="M264,-698.34C264,-691.15 264,-682.24 264,-672.71"/>
# <polygon fill="black" stroke="black" points="267.5,-672.58 264,-662.58 260.5,-672.58 267.5,-672.58"/>
# </g>
# <!-- [12]: Filter by account -->
# <g id="node5" class="node">
# <title>[12]: Filter by account</title>
# <polygon fill="none" stroke="blue" points="262.5,-491.29 123.5,-491.29 123.5,-455.29 262.5,-455.29 262.5,-491.29"/>
# <text text-anchor="middle" x="193" y="-469.59" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Filter by account</text>
# </g>
# <!-- input_collection&#45;&gt;[12]: Filter by account -->
# <g id="edge4" class="edge">
# <title>input_collection&#45;&gt;[12]: Filter by account</title>
# <path fill="none" stroke="black" d="M229.75,-536.19C222.23,-523.53 214.64,-510.74 208.33,-500.11"/>
# <polygon fill="black" stroke="black" points="211.26,-498.18 203.14,-491.37 205.24,-501.76 211.26,-498.18"/>
# </g>
# <!-- [12]: Filter by hr -->
# <g id="node11" class="node">
# <title>[12]: Filter by hr</title>
# <polygon fill="none" stroke="blue" points="401,-491.29 293,-491.29 293,-455.29 401,-455.29 401,-491.29"/>
# <text text-anchor="middle" x="347" y="-469.59" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Filter by hr</text>
# </g>
# <!-- input_collection&#45;&gt;[12]: Filter by hr -->
# <g id="edge5" class="edge">
# <title>input_collection&#45;&gt;[12]: Filter by hr</title>
# <path fill="none" stroke="black" d="M302.1,-538.99C311.61,-525.28 321.36,-511.24 329.33,-499.75"/>
# <polygon fill="black" stroke="black" points="332.22,-501.72 335.05,-491.51 326.47,-497.73 332.22,-501.72"/>
# </g>
# <!-- pcoll4363 -->
# <g id="node6" class="node">
# <title>pcoll4363</title>
# <ellipse fill="none" stroke="blue" cx="168" cy="-401.29" rx="18" ry="18"/>
# </g>
# <!-- [12]: Filter by account&#45;&gt;pcoll4363 -->
# <g id="edge6" class="edge">
# <title>[12]: Filter by account&#45;&gt;pcoll4363</title>
# <path fill="none" stroke="black" d="M186.82,-454.98C183.92,-446.87 180.41,-437.02 177.2,-428.05"/>
# <polygon fill="black" stroke="black" points="180.43,-426.67 173.77,-418.43 173.83,-429.03 180.43,-426.67"/>
# </g>
# <!-- [12]: Pair each account employee with 1 -->
# <g id="node7" class="node">
# <title>[12]: Pair each account employee with 1</title>
# <polygon fill="none" stroke="blue" points="238,-347.29 0,-347.29 0,-311.29 238,-311.29 238,-347.29"/>
# <text text-anchor="middle" x="119" y="-325.59" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Pair each account employee with 1</text>
# </g>
# <!-- pcoll4363&#45;&gt;[12]: Pair each account employee with 1 -->
# <g id="edge7" class="edge">
# <title>pcoll4363&#45;&gt;[12]: Pair each account employee with 1</title>
# <path fill="none" stroke="black" d="M158.08,-386.12C151.97,-377.38 143.94,-365.92 136.76,-355.66"/>
# <polygon fill="black" stroke="black" points="139.58,-353.59 130.98,-347.4 133.85,-357.6 139.58,-353.59"/>
# </g>
# <!-- pcoll8620 -->
# <g id="node8" class="node">
# <title>pcoll8620</title>
# <ellipse fill="none" stroke="blue" cx="119" cy="-257.29" rx="18" ry="18"/>
# </g>
# <!-- [12]: Pair each account employee with 1&#45;&gt;pcoll8620 -->
# <g id="edge8" class="edge">
# <title>[12]: Pair each account employee with 1&#45;&gt;pcoll8620</title>
# <path fill="none" stroke="black" d="M119,-310.98C119,-303.27 119,-294 119,-285.4"/>
# <polygon fill="black" stroke="black" points="122.5,-285.39 119,-275.39 115.5,-285.39 122.5,-285.39"/>
# </g>
# <!-- [12]: Count by account employee -->
# <g id="node9" class="node">
# <title>[12]: Count by account employee</title>
# <polygon fill="none" stroke="blue" points="219,-203.29 19,-203.29 19,-167.29 219,-167.29 219,-203.29"/>
# <text text-anchor="middle" x="119" y="-181.59" font-family="Times,serif" font-size="14.00" fill="blue">[12]: Count by account employee</text>
# </g>
# <!-- pcoll8620&#45;&gt;[12]: Count by account employee -->
# <g id="edge9" class="edge">
# <title>pcoll8620&#45;&gt;[12]: Count by account employee</title>
# <path fill="none" stroke="black" d="M119,-238.98C119,-231.27 119,-222 119,-213.4"/>
# <polygon fill="black" stroke="black" points="122.5,-213.39 119,-203.39 115.5,-213.39 122.5,-213.39"/>
# </g>
# <!-- accounts_count -->
# <g id="node10" class="node">
# <title>accounts_count</title>
# <ellipse fill="none" stroke="blue" cx="119" cy="-65.64" rx="65.79" ry="65.79"/>
# <text text-anchor="middle" x="119" y="-61.94" font-family="Times,serif" font-size="14.00" fill="blue">accounts_count</text>
# </g>
# <!-- [12]: Count by account employee&#45;&gt;accounts_count -->
# <g id="edge10" class="edge">
# <title>[12]: Count by account employee&#45;&gt;accounts_count</title>
# <path fill="none" stroke="black" d="M119,-167.18C119,-159.99 119,-151.09 119,-141.58"/>
# <polygon fill="black" stroke="black" points="122.5,-141.49 119,-131.49 115.5,-141.49 122.5,-141.49"/>
# </g>
# <!-- pcoll672 -->
# <g id="node12" class="node">
# <title>pcoll672</title>
# <ellipse fill="none" stroke="blue" cx="353" cy="-401.29" rx="18" ry="18"/>
# </g>
# <!-- [12]: Filter by hr&#45;&gt;pcoll672 -->
# <g id="edge11" class="edge">
# <title>[12]: Filter by hr&#45;&gt;pcoll672</title>
# <path fill="none" stroke="black" d="M348.48,-454.98C349.14,-447.27 349.94,-438 350.68,-429.4"/>
# <polygon fill="black" stroke="black" points="354.17,-429.66 351.53,-419.39 347.19,-429.06 354.17,-429.66"/>
# </g>
# <!-- [12]: Pair each hr employee with 1 -->
# <g id="node13" class="node">
# <title>[12]: Pair each hr employee with 1</title>
# <polygon fill="none" stroke="blue" points="463.5,-347.29 256.5,-347.29 256.5,-311.29 463.5,-311.29 463.5,-347.29"/>
# <text text-anchor="middle" x="360" y

# %%
class CommonTransform(beam.PTransform):
    def expand(self, input_coll):
        output_coll = (
            input_coll
            | "Pair each employee with 1" >> beam.Map(lambda e: (e[1], 1))
            | "Count by employee" >> beam.CombinePerKey(sum)
        )
        return output_coll

p1 = beam.Pipeline(InteractiveRunner())

input_collection = (
    p1
    | "Read from file" >> beam.io.ReadFromText("dept_data.txt")
    | "Split by comma" >> beam.Map(split_row)
)

## branching
accounts_count = (
    input_collection
    | "Filter by account" >> beam.Filter(lambda r: r[3] == "Accounts")
    | "Count by account employee" >> CommonTransform()
)

hr_count = (
    input_collection
    | "Filter by hr" >> beam.Filter(lambda r: r[3] == "HR")
    | "Count by hr employee" >> CommonTransform()
)

ib.show_graph(p1)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_d87a042c23d49f9fb8040a55d34baac8">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show_graph</span>
#             </div>
# /usr/bin/dot
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="396pt" height="742pt"
#  viewBox="0.00 0.00 395.50 742.48" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 738.48)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-738.48 391.5,-738.48 391.5,4 -4,4"/>
# <!-- [15]: Read from file -->
# <g id="node1" class="node">
# <title>[15]: Read from file</title>
# <polygon fill="none" stroke="blue" points="279.5,-734.48 152.5,-734.48 152.5,-698.48 279.5,-698.48 279.5,-734.48"/>
# <text text-anchor="middle" x="216" y="-712.78" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Read from file</text>
# </g>
# <!-- pcoll9226 -->
# <g id="node2" class="node">
# <title>pcoll9226</title>
# <ellipse fill="none" stroke="blue" cx="216" cy="-644.48" rx="18" ry="18"/>
# </g>
# <!-- [15]: Read from file&#45;&gt;pcoll9226 -->
# <g id="edge1" class="edge">
# <title>[15]: Read from file&#45;&gt;pcoll9226</title>
# <path fill="none" stroke="black" d="M216,-698.17C216,-690.46 216,-681.19 216,-672.59"/>
# <polygon fill="black" stroke="black" points="219.5,-672.58 216,-662.58 212.5,-672.58 219.5,-672.58"/>
# </g>
# <!-- [15]: Split by comma -->
# <g id="node3" class="node">
# <title>[15]: Split by comma</title>
# <polygon fill="none" stroke="blue" points="283,-590.48 149,-590.48 149,-554.48 283,-554.48 283,-590.48"/>
# <text text-anchor="middle" x="216" y="-568.78" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Split by comma</text>
# </g>
# <!-- pcoll9226&#45;&gt;[15]: Split by comma -->
# <g id="edge2" class="edge">
# <title>pcoll9226&#45;&gt;[15]: Split by comma</title>
# <path fill="none" stroke="black" d="M216,-626.17C216,-618.46 216,-609.19 216,-600.59"/>
# <polygon fill="black" stroke="black" points="219.5,-600.58 216,-590.58 212.5,-600.58 219.5,-600.58"/>
# </g>
# <!-- input_collection -->
# <g id="node4" class="node">
# <title>input_collection</title>
# <ellipse fill="none" stroke="blue" cx="216" cy="-450.88" rx="67.69" ry="67.69"/>
# <text text-anchor="middle" x="216" y="-447.18" font-family="Times,serif" font-size="14.00" fill="blue">input_collection</text>
# </g>
# <!-- [15]: Split by comma&#45;&gt;input_collection -->
# <g id="edge3" class="edge">
# <title>[15]: Split by comma&#45;&gt;input_collection</title>
# <path fill="none" stroke="black" d="M216,-554.34C216,-547.15 216,-538.24 216,-528.71"/>
# <polygon fill="black" stroke="black" points="219.5,-528.58 216,-518.58 212.5,-528.58 219.5,-528.58"/>
# </g>
# <!-- [15]: Filter by account -->
# <g id="node5" class="node">
# <title>[15]: Filter by account</title>
# <polygon fill="none" stroke="blue" points="214.5,-347.29 75.5,-347.29 75.5,-311.29 214.5,-311.29 214.5,-347.29"/>
# <text text-anchor="middle" x="145" y="-325.59" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Filter by account</text>
# </g>
# <!-- input_collection&#45;&gt;[15]: Filter by account -->
# <g id="edge4" class="edge">
# <title>input_collection&#45;&gt;[15]: Filter by account</title>
# <path fill="none" stroke="black" d="M181.75,-392.19C174.23,-379.53 166.64,-366.74 160.33,-356.11"/>
# <polygon fill="black" stroke="black" points="163.26,-354.18 155.14,-347.37 157.24,-357.76 163.26,-354.18"/>
# </g>
# <!-- [15]: Filter by hr -->
# <g id="node9" class="node">
# <title>[15]: Filter by hr</title>
# <polygon fill="none" stroke="blue" points="349,-347.29 241,-347.29 241,-311.29 349,-311.29 349,-347.29"/>
# <text text-anchor="middle" x="295" y="-325.59" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Filter by hr</text>
# </g>
# <!-- input_collection&#45;&gt;[15]: Filter by hr -->
# <g id="edge5" class="edge">
# <title>input_collection&#45;&gt;[15]: Filter by hr</title>
# <path fill="none" stroke="black" d="M252.96,-393.94C261.76,-380.6 270.74,-367.01 278.13,-355.83"/>
# <polygon fill="black" stroke="black" points="281.09,-357.7 283.68,-347.43 275.24,-353.85 281.09,-357.7"/>
# </g>
# <!-- pcoll4363 -->
# <g id="node6" class="node">
# <title>pcoll4363</title>
# <ellipse fill="none" stroke="blue" cx="130" cy="-257.29" rx="18" ry="18"/>
# </g>
# <!-- [15]: Filter by account&#45;&gt;pcoll4363 -->
# <g id="edge6" class="edge">
# <title>[15]: Filter by account&#45;&gt;pcoll4363</title>
# <path fill="none" stroke="black" d="M141.29,-310.98C139.64,-303.27 137.65,-294 135.81,-285.4"/>
# <polygon fill="black" stroke="black" points="139.18,-284.44 133.67,-275.39 132.34,-285.9 139.18,-284.44"/>
# </g>
# <!-- [15]: Count by account employee -->
# <g id="node7" class="node">
# <title>[15]: Count by account employee</title>
# <polygon fill="none" stroke="blue" points="200,-203.29 0,-203.29 0,-167.29 200,-167.29 200,-203.29"/>
# <text text-anchor="middle" x="100" y="-181.59" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Count by account employee</text>
# </g>
# <!-- pcoll4363&#45;&gt;[15]: Count by account employee -->
# <g id="edge7" class="edge">
# <title>pcoll4363&#45;&gt;[15]: Count by account employee</title>
# <path fill="none" stroke="black" d="M123.19,-240.4C119.7,-232.26 115.36,-222.13 111.38,-212.84"/>
# <polygon fill="black" stroke="black" points="114.57,-211.39 107.41,-203.58 108.13,-214.15 114.57,-211.39"/>
# </g>
# <!-- accounts_count -->
# <g id="node8" class="node">
# <title>accounts_count</title>
# <ellipse fill="none" stroke="blue" cx="100" cy="-65.64" rx="65.79" ry="65.79"/>
# <text text-anchor="middle" x="100" y="-61.94" font-family="Times,serif" font-size="14.00" fill="blue">accounts_count</text>
# </g>
# <!-- [15]: Count by account employee&#45;&gt;accounts_count -->
# <g id="edge8" class="edge">
# <title>[15]: Count by account employee&#45;&gt;accounts_count</title>
# <path fill="none" stroke="black" d="M100,-167.18C100,-159.99 100,-151.09 100,-141.58"/>
# <polygon fill="black" stroke="black" points="103.5,-141.49 100,-131.49 96.5,-141.49 103.5,-141.49"/>
# </g>
# <!-- pcoll672 -->
# <g id="node10" class="node">
# <title>pcoll672</title>
# <ellipse fill="none" stroke="blue" cx="299" cy="-257.29" rx="18" ry="18"/>
# </g>
# <!-- [15]: Filter by hr&#45;&gt;pcoll672 -->
# <g id="edge9" class="edge">
# <title>[15]: Filter by hr&#45;&gt;pcoll672</title>
# <path fill="none" stroke="black" d="M295.99,-310.98C296.43,-303.27 296.96,-294 297.45,-285.4"/>
# <polygon fill="black" stroke="black" points="300.95,-285.58 298.02,-275.39 293.96,-285.18 300.95,-285.58"/>
# </g>
# <!-- [15]: Count by hr employee -->
# <g id="node11" class="node">
# <title>[15]: Count by hr employee</title>
# <polygon fill="none" stroke="blue" points="387.5,-203.29 218.5,-203.29 218.5,-167.29 387.5,-167.29 387.5,-203.29"/>
# <text text-anchor="middle" x="303" y="-181.59" font-family="Times,serif" font-size="14.00" fill="blue">[15]: Count by hr employee</text>
# </g>
# <!-- pcoll672&#45;&gt;[15]: Count by hr employee -->
# <g id="edge10" class="edge">
# <title>pcoll672&#45;&gt;[15]: Count by hr employee</title>
# <path fill="none" stroke="black" d="M299.99,-238.98C300.43,-231.27 300.96,-222 301.45,-213.4"/>
# <polygon fill="black" stroke="black" points="304.95,-213.58 302.02,-203.39 297.96,-213.18 304.95,-213.58"/>
# </g>
# <!-- hr_count -->
# <g id="node12" class="node">
# <title>hr_count</title>
# <ellipse fill="none" stroke="blue" cx="303" cy="-65.64" rx="42.49" ry="42.49"/>
# <text text-anchor="middle" x="303" y="-61.94" font-family="Times,serif" font-size="14.00" fill="blue">hr_count</text>
# </g>
# <!-- [15]: Count by hr employee&#45;&gt;hr_count -->
# <g id="edge11" class="edge">
# <title>[15]: Count by hr employee&#45;&gt;hr_count</title>
# <path fill="none" stroke="black" d="M303,-167.18C303,-154.24 303,-135.74 303,-118.13"/>
# <polygon fill="black" stroke="black" points="306.5,-117.91 303,-107.91 299.5,-117.92 306.5,-117.91"/>
# </g>
# </g>
# </svg>
