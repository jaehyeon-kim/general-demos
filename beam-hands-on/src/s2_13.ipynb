# %%
import apache_beam as beam
import apache_beam.runners.interactive.interactive_beam as ib
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner

# %%
def split_row(e: str):
    return e.split(",")

# %%
p = beam.Pipeline(InteractiveRunner())

input_collection = (
    p
    | "Read from file" >> beam.io.ReadFromText("dept_data.txt")
    | "Split by comma" >> beam.Map(split_row)
)

## branching
accounts_count = (
    input_collection
    | "Filter by account" >> beam.Filter(lambda r: r[3] == "Accounts")
    | "Pair each account employee with 1" >> beam.Map(lambda e: (e[1], 1))
    | "Count by account employee" >> beam.CombinePerKey(sum)
)

hr_count = (
    input_collection
    | "Filter by hr" >> beam.Filter(lambda r: r[3] == "HR")
    | "Pair each hr employee with 1" >> beam.Map(lambda e: (e[1], 1))
    | "Count by hr employee" >> beam.CombinePerKey(sum)
)

## flatten - union
output = (
    (accounts_count, hr_count)
    | "Combinding records" >> beam.Flatten()
)

ib.show(output, n=5)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_bf544f16cb98ab502077164b7d189e04">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_0feb2d317ddb5c19cbe78f43f0966c8b" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b")) {
#               dt = $("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b").dataTable();
#             } else if ($("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b_wrapper").length == 0) {
#               dt = $("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'output.0'}, {'title': 'output.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Marco', 2: '31', 0: 0}, {1: 'Rebekah', 2: '31', 0: 1}, {1: 'Itoe', 2: '31', 0: 2}, {1: 'Edouard', 2: '31', 0: 3}, {1: 'Kyle', 2: '62', 0: 4}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b")) {
#               dt = $("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b").dataTable();
#             } else if ($("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b_wrapper").length == 0) {
#               dt = $("#table_df_0feb2d317ddb5c19cbe78f43f0966c8b").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'output.0'}, {'title': 'output.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Marco', 2: '31', 0: 0}, {1: 'Rebekah', 2: '31', 0: 1}, {1: 'Itoe', 2: '31', 0: 2}, {1: 'Edouard', 2: '31', 0: 3}, {1: 'Kyle', 2: '62', 0: 4}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
ib.show_graph(p)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_0720eabdf90b7c5c0fa5b0924ced56af">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show_graph</span>
#             </div>
# /usr/bin/dot
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="472pt" height="1061pt"
#  viewBox="0.00 0.00 471.50 1060.77" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1056.77)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-1056.77 467.5,-1056.77 467.5,4 -4,4"/>
# <!-- [22]: Read from file -->
# <g id="node1" class="node">
# <title>[22]: Read from file</title>
# <polygon fill="none" stroke="blue" points="327.5,-1052.77 200.5,-1052.77 200.5,-1016.77 327.5,-1016.77 327.5,-1052.77"/>
# <text text-anchor="middle" x="264" y="-1031.07" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Read from file</text>
# </g>
# <!-- pcoll5578 -->
# <g id="node2" class="node">
# <title>pcoll5578</title>
# <ellipse fill="none" stroke="blue" cx="264" cy="-962.77" rx="18" ry="18"/>
# </g>
# <!-- [22]: Read from file&#45;&gt;pcoll5578 -->
# <g id="edge1" class="edge">
# <title>[22]: Read from file&#45;&gt;pcoll5578</title>
# <path fill="none" stroke="black" d="M264,-1016.47C264,-1008.75 264,-999.48 264,-990.88"/>
# <polygon fill="black" stroke="black" points="267.5,-990.87 264,-980.87 260.5,-990.87 267.5,-990.87"/>
# </g>
# <!-- [22]: Split by comma -->
# <g id="node3" class="node">
# <title>[22]: Split by comma</title>
# <polygon fill="none" stroke="blue" points="331,-908.77 197,-908.77 197,-872.77 331,-872.77 331,-908.77"/>
# <text text-anchor="middle" x="264" y="-887.07" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Split by comma</text>
# </g>
# <!-- pcoll5578&#45;&gt;[22]: Split by comma -->
# <g id="edge2" class="edge">
# <title>pcoll5578&#45;&gt;[22]: Split by comma</title>
# <path fill="none" stroke="black" d="M264,-944.47C264,-936.75 264,-927.48 264,-918.88"/>
# <polygon fill="black" stroke="black" points="267.5,-918.87 264,-908.87 260.5,-918.87 267.5,-918.87"/>
# </g>
# <!-- input_collection -->
# <g id="node4" class="node">
# <title>input_collection</title>
# <ellipse fill="none" stroke="blue" cx="264" cy="-769.18" rx="67.69" ry="67.69"/>
# <text text-anchor="middle" x="264" y="-765.48" font-family="Times,serif" font-size="14.00" fill="blue">input_collection</text>
# </g>
# <!-- [22]: Split by comma&#45;&gt;input_collection -->
# <g id="edge3" class="edge">
# <title>[22]: Split by comma&#45;&gt;input_collection</title>
# <path fill="none" stroke="black" d="M264,-872.64C264,-865.45 264,-856.54 264,-847"/>
# <polygon fill="black" stroke="black" points="267.5,-846.88 264,-836.88 260.5,-846.88 267.5,-846.88"/>
# </g>
# <!-- [22]: Filter by account -->
# <g id="node5" class="node">
# <title>[22]: Filter by account</title>
# <polygon fill="none" stroke="blue" points="262.5,-665.58 123.5,-665.58 123.5,-629.58 262.5,-629.58 262.5,-665.58"/>
# <text text-anchor="middle" x="193" y="-643.88" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Filter by account</text>
# </g>
# <!-- input_collection&#45;&gt;[22]: Filter by account -->
# <g id="edge4" class="edge">
# <title>input_collection&#45;&gt;[22]: Filter by account</title>
# <path fill="none" stroke="black" d="M229.75,-710.48C222.23,-697.82 214.64,-685.04 208.33,-674.4"/>
# <polygon fill="black" stroke="black" points="211.26,-672.48 203.14,-665.66 205.24,-676.05 211.26,-672.48"/>
# </g>
# <!-- [22]: Filter by hr -->
# <g id="node11" class="node">
# <title>[22]: Filter by hr</title>
# <polygon fill="none" stroke="blue" points="401,-665.58 293,-665.58 293,-629.58 401,-629.58 401,-665.58"/>
# <text text-anchor="middle" x="347" y="-643.88" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Filter by hr</text>
# </g>
# <!-- input_collection&#45;&gt;[22]: Filter by hr -->
# <g id="edge5" class="edge">
# <title>input_collection&#45;&gt;[22]: Filter by hr</title>
# <path fill="none" stroke="black" d="M302.1,-713.28C311.61,-699.58 321.36,-685.53 329.33,-674.04"/>
# <polygon fill="black" stroke="black" points="332.22,-676.02 335.05,-665.8 326.47,-672.02 332.22,-676.02"/>
# </g>
# <!-- pcoll4247 -->
# <g id="node6" class="node">
# <title>pcoll4247</title>
# <ellipse fill="none" stroke="blue" cx="168" cy="-575.58" rx="18" ry="18"/>
# </g>
# <!-- [22]: Filter by account&#45;&gt;pcoll4247 -->
# <g id="edge6" class="edge">
# <title>[22]: Filter by account&#45;&gt;pcoll4247</title>
# <path fill="none" stroke="black" d="M186.82,-629.28C183.92,-621.16 180.41,-611.32 177.2,-602.35"/>
# <polygon fill="black" stroke="black" points="180.43,-600.97 173.77,-592.73 173.83,-603.32 180.43,-600.97"/>
# </g>
# <!-- [22]: Pair each account employee with 1 -->
# <g id="node7" class="node">
# <title>[22]: Pair each account employee with 1</title>
# <polygon fill="none" stroke="blue" points="238,-521.58 0,-521.58 0,-485.58 238,-485.58 238,-521.58"/>
# <text text-anchor="middle" x="119" y="-499.88" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Pair each account employee with 1</text>
# </g>
# <!-- pcoll4247&#45;&gt;[22]: Pair each account employee with 1 -->
# <g id="edge7" class="edge">
# <title>pcoll4247&#45;&gt;[22]: Pair each account employee with 1</title>
# <path fill="none" stroke="black" d="M158.08,-560.42C151.97,-551.68 143.94,-540.21 136.76,-529.95"/>
# <polygon fill="black" stroke="black" points="139.58,-527.88 130.98,-521.7 133.85,-531.89 139.58,-527.88"/>
# </g>
# <!-- pcoll3809 -->
# <g id="node8" class="node">
# <title>pcoll3809</title>
# <ellipse fill="none" stroke="blue" cx="128" cy="-431.58" rx="18" ry="18"/>
# </g>
# <!-- [22]: Pair each account employee with 1&#45;&gt;pcoll3809 -->
# <g id="edge8" class="edge">
# <title>[22]: Pair each account employee with 1&#45;&gt;pcoll3809</title>
# <path fill="none" stroke="black" d="M121.22,-485.28C122.22,-477.57 123.41,-468.29 124.51,-459.69"/>
# <polygon fill="black" stroke="black" points="128,-460.05 125.8,-449.69 121.05,-459.16 128,-460.05"/>
# </g>
# <!-- [22]: Count by account employee -->
# <g id="node9" class="node">
# <title>[22]: Count by account employee</title>
# <polygon fill="none" stroke="blue" points="247,-377.58 47,-377.58 47,-341.58 247,-341.58 247,-377.58"/>
# <text text-anchor="middle" x="147" y="-355.88" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Count by account employee</text>
# </g>
# <!-- pcoll3809&#45;&gt;[22]: Count by account employee -->
# <g id="edge9" class="edge">
# <title>pcoll3809&#45;&gt;[22]: Count by account employee</title>
# <path fill="none" stroke="black" d="M132.5,-413.99C134.62,-406.21 137.19,-396.72 139.58,-387.91"/>
# <polygon fill="black" stroke="black" points="143.02,-388.6 142.26,-378.03 136.27,-386.76 143.02,-388.6"/>
# </g>
# <!-- accounts_count -->
# <g id="node10" class="node">
# <title>accounts_count</title>
# <ellipse fill="none" stroke="blue" cx="185" cy="-239.94" rx="65.79" ry="65.79"/>
# <text text-anchor="middle" x="185" y="-236.24" font-family="Times,serif" font-size="14.00" fill="blue">accounts_count</text>
# </g>
# <!-- [22]: Count by account employee&#45;&gt;accounts_count -->
# <g id="edge10" class="edge">
# <title>[22]: Count by account employee&#45;&gt;accounts_count</title>
# <path fill="none" stroke="black" d="M152.53,-341.48C155.14,-333.39 158.45,-323.14 161.95,-312.3"/>
# <polygon fill="black" stroke="black" points="165.32,-313.25 165.07,-302.65 158.66,-311.09 165.32,-313.25"/>
# </g>
# <!-- [22]: Combinding records -->
# <g id="node17" class="node">
# <title>[22]: Combinding records</title>
# <polygon fill="none" stroke="blue" points="327,-138.29 169,-138.29 169,-102.29 327,-102.29 327,-138.29"/>
# <text text-anchor="middle" x="248" y="-116.59" font-family="Times,serif" font-size="14.00" fill="blue">[22]: Combinding records</text>
# </g>
# <!-- accounts_count&#45;&gt;[22]: Combinding records -->
# <g id="edge11" class="edge">
# <title>accounts_count&#45;&gt;[22]: Combinding records</title>
# <path fill="none" stroke="black" d="M215.58,-181.84C221.99,-169.86 228.46,-157.79 233.91,-147.61"/>
# <polygon fill="black" stroke="black" points="237.15,-148.96 238.79,-138.49 230.98,-145.66 237.15,-14
