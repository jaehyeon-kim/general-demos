# %%
import apache_beam as beam
from apache_beam.runners.interactive import interactive_runner
from apache_beam.runners.interactive.interactive_beam import *

# %%
p = beam.Pipeline(interactive_runner.InteractiveRunner())

# %%
init_pcoll = p |  beam.Create(range(10))
show(init_pcoll)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_8006216c2e42018c6351df04c3f34949">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_99a18dad250998e7d5076b3e49f269a0" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_99a18dad250998e7d5076b3e49f269a0")) {
#               dt = $("#table_df_99a18dad250998e7d5076b3e49f269a0").dataTable();
#             } else if ($("#table_df_99a18dad250998e7d5076b3e49f269a0_wrapper").length == 0) {
#               dt = $("#table_df_99a18dad250998e7d5076b3e49f269a0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'init_pcoll.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '2', 0: 2}, {1: '3', 0: 3}, {1: '4', 0: 4}, {1: '5', 0: 5}, {1: '6', 0: 6}, {1: '7', 0: 7}, {1: '8', 0: 8}, {1: '9', 0: 9}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_99a18dad250998e7d5076b3e49f269a0")) {
#               dt = $("#table_df_99a18dad250998e7d5076b3e49f269a0").dataTable();
#             } else if ($("#table_df_99a18dad250998e7d5076b3e49f269a0_wrapper").length == 0) {
#               dt = $("#table_df_99a18dad250998e7d5076b3e49f269a0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'init_pcoll.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '2', 0: 2}, {1: '3', 0: 3}, {1: '4', 0: 4}, {1: '5', 0: 5}, {1: '6', 0: 6}, {1: '7', 0: 7}, {1: '8', 0: 8}, {1: '9', 0: 9}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
squares = init_pcoll | 'Square' >> beam.Map(lambda x: x*x)
show(squares)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_bcc5bd400f47c860ee9edaedca9aa289">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_77ab36f2183fd8f02cde840a088fd5fd" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_77ab36f2183fd8f02cde840a088fd5fd")) {
#               dt = $("#table_df_77ab36f2183fd8f02cde840a088fd5fd").dataTable();
#             } else if ($("#table_df_77ab36f2183fd8f02cde840a088fd5fd_wrapper").length == 0) {
#               dt = $("#table_df_77ab36f2183fd8f02cde840a088fd5fd").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'squares.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '4', 0: 2}, {1: '9', 0: 3}, {1: '16', 0: 4}, {1: '25', 0: 5}, {1: '36', 0: 6}, {1: '49', 0: 7}, {1: '64', 0: 8}, {1: '81', 0: 9}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_77ab36f2183fd8f02cde840a088fd5fd")) {
#               dt = $("#table_df_77ab36f2183fd8f02cde840a088fd5fd").dataTable();
#             } else if ($("#table_df_77ab36f2183fd8f02cde840a088fd5fd_wrapper").length == 0) {
#               dt = $("#table_df_77ab36f2183fd8f02cde840a088fd5fd").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'squares.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '4', 0: 2}, {1: '9', 0: 3}, {1: '16', 0: 4}, {1: '25', 0: 5}, {1: '36', 0: 6}, {1: '49', 0: 7}, {1: '64', 0: 8}, {1: '81', 0: 9}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
cubes = init_pcoll | 'Cube' >> beam.Map(lambda x: x**3)
show(cubes)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_2949e4e26c98c6d0856379f2d95d5614">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6")) {
#               dt = $("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6").dataTable();
#             } else if ($("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6_wrapper").length == 0) {
#               dt = $("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'cubes.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '8', 0: 2}, {1: '27', 0: 3}, {1: '64', 0: 4}, {1: '125', 0: 5}, {1: '216', 0: 6}, {1: '343', 0: 7}, {1: '512', 0: 8}, {1: '729', 0: 9}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6")) {
#               dt = $("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6").dataTable();
#             } else if ($("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6_wrapper").length == 0) {
#               dt = $("#table_df_f4d0b5fbc0d8311d8c15a0ee44250bf6").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'cubes.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '0', 0: 0}, {1: '1', 0: 1}, {1: '8', 0: 2}, {1: '27', 0: 3}, {1: '64', 0: 4}, {1: '125', 0: 5}, {1: '216', 0: 6}, {1: '343', 0: 7}, {1: '512', 0: 8}, {1: '729', 0: 9}])
#               .draw('full-hold');
#           });
#         }
#             </script>
